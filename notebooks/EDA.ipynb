# %%
# Celda 1: Importaciones y carga de datos
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# Cargar datos
df = pd.read_csv('../vehicles_us.csv')

# Vista rápida del dataset
print('Filas, columnas:', df.shape)
df.head()
# Out:
# Filas, columnas: (51525, 13)
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
# Celda 2: Inspección rápida de valores faltantes
missing = df.isna().sum().sort_values(ascending=False)
missing_pct = (missing / len(df) * 100).round(2)
pd.DataFrame({'faltantes': missing, 'porcentaje_%': missing_pct})
# Out:
#               faltantes  porcentaje_%
# is_4wd            25953         50.37
# paint_color        9267         17.99
# odometer           7892         15.32
# cylinders          5260         10.21
# model_year         3619          7.02
# condition             0          0.00
# model                 0          0.00
# price                 0          0.00
# fuel                  0          0.00
# type                  0          0.00
# transmission          0          0.00
# date_posted           0          0.00
# days_listed           0          0.00

# %%
# Celda 3: Separar marca y nombre del modelo (limpieza básica de texto)
# Asumimos: primera palabra = marca, resto = nombre del modelo
split = df['model'].str.split(' ', n=1, expand=True)
df['brand'] = split[0].str.capitalize().str.strip()
df['model_name'] = split[1].str.lower().str.strip().fillna('')

# Normalizar la columna 'model' (solo primera palabra)
df['model'] = df['model'].str.split().str[0].str.capitalize()

# Revisión
df[['model', 'brand', 'model_name']].head(10)
# Out:
#       model     brand model_name
# 0       Bmw       Bmw         x5
# 1      Ford      Ford      f-150
# 2   Hyundai   Hyundai     sonata
# 3      Ford      Ford      f-150
# 4  Chrysler  Chrysler        200
# 5  Chrysler  Chrysler        300
# 6    Toyota    Toyota      camry
# 7     Honda     Honda      pilot
# 8       Kia       Kia    sorento
# 9     Honda     Honda      pilot

# %%
# Celda 4: Estrategia de imputación y limpieza
# Crear copia para no modificar el original
df_clean = df.copy()

# Eliminar filas con NaN en columnas numéricas clave
df_clean.dropna(subset=['model_year', 'cylinders', 'odometer'], inplace=True)

# Convertir a tipo entero
df_clean['model_year'] = df_clean['model_year'].astype(int)
df_clean['cylinders'] = df_clean['cylinders'].astype(int)
df_clean['odometer'] = df_clean['odometer'].astype(int)

# Imputar color de pintura desconocido
df_clean['paint_color'] = df_clean['paint_color'].fillna('unknown')

# Imputar tracción 4WD (0 = no tiene)
df_clean['is_4wd'] = df_clean['is_4wd'].fillna(0).astype(int)

# Comprobar que no quedan valores faltantes
df_clean[['model_year', 'cylinders', 'odometer', 'paint_color', 'is_4wd']].isna().sum()
# Out:
# model_year     0
# cylinders      0
# odometer       0
# paint_color    0
# is_4wd         0
# dtype: int64

# %%
# Celda 5: Transformaciones adicionales
CURRENT_YEAR = 2025

# Antigüedad del vehículo (evitar valores negativos)
df_clean['vehicle_age'] = (CURRENT_YEAR - df_clean['model_year']).clip(lower=0)

# Precio por milla (proteger división por cero)
df_clean['price'] = pd.to_numeric(df_clean['price'], errors='coerce').fillna(0)
df_clean['price_per_mile'] = df_clean.apply(
    lambda r: r['price'] / r['odometer'] if r['odometer'] > 0 else np.nan, axis=1
)

# Categoría de precio
df_clean['price_category'] = pd.cut(
    df_clean['price'],
    bins=[-1, 5000, 15000, 30000, 1_000_000],
    labels=['bajo', 'medio', 'alto', 'lujo']
)

# Normalizar columna 'condition' a minúsculas
if 'condition' in df_clean.columns:
    df_clean['condition'] = (df_clean['condition'].astype(str)
                             .str.lower().str.strip()
                             .replace({'nan': 'unknown'}))
else:
    df_clean['condition'] = 'unknown'

# Limpiar todas las columnas de texto: eliminar espacios vacios de los extremos,
# capitalizar cada palabra y cambiar espacios por '_'
cols_texto = df_clean.select_dtypes(include=['object', 'category']).columns
for col in cols_texto:
    if col != 'date_posted':
        df_clean[col] = df_clean[col].astype(str).str.strip().str.title().str.replace(' ', '_')

df_clean.head()
# Out:
#    price  model_year     model  condition  cylinders fuel  odometer  \
# 0   9400        2011       Bmw       Good          6  Gas    145000
# 2   5500        2013   Hyundai   Like_New          4  Gas    110000
# 4  14900        2017  Chrysler  Excellent          4  Gas     80903
# 5  14990        2014  Chrysler  Excellent          6  Gas     57954
# 6  12990        2015    Toyota  Excellent          4  Gas     79212
#
#   transmission   type paint_color  is_4wd date_posted  days_listed     brand  \
# 0    Automatic    Suv     Unknown       1  2018-06-23           19       Bmw
# 2    Automatic  Sedan         Red       0  2019-02-07           79   Hyundai
# 4    Automatic  Sedan       Black       0  2019-04-02           28  Chrysler
# 5    Automatic  Sedan       Black       1  2018-06-20           15  Chrysler
# 6    Automatic  Sedan       White       0  2018-12-27           73    Toyota
#
#   model_name  vehicle_age  price_per_mile price_category
# ...

# %%
# Celda 6: Gráfico Sunburst — Conteo de vehículos por marca y modelo
fig_sun = px.sunburst(
    df_clean,
    path=['brand', 'model_name'],
    values=None,  # None => cuenta ocurrencias
    title='Distribución de Vehículos por Marca y Modelo',
    color='brand'
)
fig_sun.update_traces(textinfo='label+percent entry')
fig_sun.show()

# %%
# Celda 7: Histograma — Condición vs. Año del modelo
fig_hist = px.histogram(
    df_clean,
    x='model_year',
    color='condition',
    title='Distribución de Condición por Año del Modelo',
    barmode='stack',
    labels={
        'model_year': 'Año del Modelo',
        'condition': 'Condición',
        'count': 'Cantidad'
    }
)
fig_hist.show()

# %%
# Celda 8: Gráfico de Dispersión — Precio vs. Año (color = Odómetro)
fig_scatter = go.Figure(
    data=[
        go.Scatter(
            x=df_clean['model_year'],
            y=df_clean['price'],
            mode='markers',
            customdata=df_clean[['brand', 'model_name']].values,
            marker=dict(
                size=8,
                opacity=0.7,
                color=df_clean['odometer'],
                colorscale='Sunset',
                line=dict(width=0.5, color='white'),
                showscale=True,
                colorbar=dict(
                    title=dict(
                        text='<b>Millaje (Millas)</b>',
                        font=dict(size=12, color='#555555')
                    ),
                    thickness=12,
                    len=0.75,
                    outlinewidth=0,
                    tickfont=dict(color='#7F8C8D'),
                    tickformat=',.0f'
                )
            ),
            hovertemplate=(
                '<b>Marca:</b> %{customdata[0]}<br>'
                '<b>Modelo:</b> %{customdata[1]}<br>'
                '<b>Odómetro:</b> %{marker.color:,.0f} millas<br>'
                '<b>Año:</b> %{x}<br>'
                '<b>Precio:</b> $%{y:,.0f}<br>'
                '<extra></extra>'
            )
        )
    ]
)

fig_scatter.update_layout(
    title=dict(
        text='Relación entre <b>Precio</b>, <b>Año</b> y <b>Millaje</b>',
        font=dict(size=22, color='#2C3E50', family='Arial, sans-serif'),
        x=0.05,
        y=0.95
    ),
    xaxis=dict(
        title='Año de Fabricación',
        showgrid=True,
        gridcolor='#F0F4F8',
        linecolor='#D5DDE5',
        zeroline=False,
        tickfont=dict(color='#7F8C8D')
    ),
    yaxis=dict(
        title='Precio (USD)',
        showgrid=True,
        gridcolor='#F0F4F8',
        linecolor='#D5DDE5',
        zeroline=False,
        tickformat='$,.0f',
        tickfont=dict(color='#7F8C8D')
    ),
    plot_bgcolor='white',
    paper_bgcolor='white',
    margin=dict(l=60, r=40, t=80, b=60),
    hoverlabel=dict(
        bgcolor='white',
        font_size=14,
        font_family='Arial, sans-serif'
    )
)

fig_scatter.show()

# %%
# Celda 9: Grafico de Barras Apiladas - Tipos de vehiculos por marca
# Usamos px.histogram para contar automaticamente o agrupamos primero.
# px.histogram es ideal para contar ocurrencias.
fig_bar = px.histogram(
    df_clean,
    x='model',
    color='type',
    title='Tipos de Vehiculos por Marca',
    labels={
        'model': 'Marca',
        'type': 'Tipo'
    }
)

# Ajustes visuales y orden descendente
fig_bar.update_layout(
    barmode='stack',
    xaxis={'categoryorder': 'total descending'},
    title_x=0.5,
    yaxis_title="Unidades"
)
fig_bar.show()
